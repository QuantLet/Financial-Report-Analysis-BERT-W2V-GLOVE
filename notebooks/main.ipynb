# %%
# %pip install transformers
# %pip install PyPDF2
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.38)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.28.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.85)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.11.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.17.5)
# Requirement already satisfied: tokenizers==0.0.11 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.11)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.9.4)
# Requirement already satisfied: botocore<1.15.0,>=1.14.9 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (1.14.9)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.3.2)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers) (2.6.1)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.6/dist-packages (1.26.0)

# %%
# %rm -rf BERT_financialReportAnalysis/

# %%
# !git clone https://github.com/francisliu2/BERT_financialReportAnalysis.git
# Out:
# Cloning into 'BERT_financialReportAnalysis'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 28 (delta 13), reused 22 (delta 7), pack-reused 0
# Unpacking objects: 100% (28/28), done.

# %%
# %cd BERT_financialReportAnalysis/
# Out:
# /content/BERT_financialReportAnalysis

# %%
from companytoVector_BERT import *
from corporate_profile_extrator import *

from google.colab import files
import os
import glob

os.mkdir('outputs')
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Max number of tokens in one sentence: 512

# %%
CP = glob.glob("./data/*.pdf")

# %%
model = load_model()

# %%
# %time result = company2vector(corporate_profile_1, model)
# Out:
# CPU times: user 26.9 s, sys: 620 ms, total: 27.5 s
# Wall time: 27.5 s

# %%
for i in range(len(CP)):
  name = CP[i].replace('.pdf', '') 
  name = name.replace('./data/', '')
  corporate_profile_text = get_corporate_profile(CP[i])
  result = company2vector(corporate_profile_text, model)
  np.save(name, result)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-9-576db04dd9e2> in <module>()
#       2   name = CP[i].replace('.pdf', '')
#       3   name = name.replace('./data/', '')
# ----> 4   corporate_profile_text = get_corporate_profile(CP[i])
#       5   result = company2vector(corporate_profile_text, model)
#       6   np.save(name, result)
#
# /content/BERT_financialReportAnalysis/corporate_profile_extrator.py in get_corporate_profile(file_name)
#      26             corporate_profile = page_content
#      27             break
# ---> 28     return corporate_profile
#
# UnboundLocalError: local variable 'corporate_profile' referenced before assignment

# %%
name
# Out:
# 'China Star_Sustainability Report'

# %%
file_name = CP[1]
pdf_file = open(file_name, 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
number_of_pages = read_pdf.getNumPages()
regex = r"corporate[\s{,3} \n]pro"

for p in range(number_of_pages):
    page = read_pdf.getPage(p)
    page_content = page.extractText()
    page_content = f_correction(page_content)

    match = re.search(regex, page_content.lower())
    # match = re.search(regex, 'corporate  pro')
    print(match)
# Out:
# None
# <_sre.SRE_Match object; span=(314, 327), match='corporate pro'>
# <_sre.SRE_Match object; span=(141, 154), match='corporate pro'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <_sre.SRE_Match object; span=(501, 514), match='corporate pro'>
# None
# None
# None
# None
# None
# None

# %%
match

# %%
regex = r"h"
text = page_content.lower().encode(encoding='UTF-8').decode()
match = re.search(text, regex)
print(match)
# Out:
# None

# %%
text
# Out:
# 'corporate pro˜le\nsteel is increasingly the material of choice for the \nconstruction of buildings and temporary support for \ndeep excavations. the advantages of using steel over \nconventional material such as concrete for building \n\nconstruction are numerous. the higher speed of \nconstruction, superior material strength to volume ratio, \n˜exibility in design and aesthetics are just some of the \n\nbene˚ts of using steel.with 40 years of experience in steel fabrication, \nyongnam excels in adding value to steel construction. \nthe group™s two production facilities in singapore and \nnusajaya, johor, malaysia have a total annual production \n\ncapacity of 78,000 tonnes of steel fabrication. yongnam \nutilizes the latest fabrication technologies and design \ninnovation to offer solutions to its clients on a fast-\n\ntrack basis. our modular strutting system continues to \ngive the group a strong competitive edge in meeting \nincreasingly stringent design and project requirements \n\nin infrastructure and construction projects. with a \ntraceability procedure that meets the requirements of \nthe singapore building and construction authority, our \nmodular strutting system is the ˚rst to be certi˚ed by an \n\nindependent auditor for reusability in earth retaining or \nstabilizing structures.\nyongnam™s technical and value engineering solutions for \nsteel fabrication and erection have resulted in increased \nproductivity, improved yield and lower costs. our in-\n\nhouse pool of experienced and quali˚ed engineers, \ndetailers, technicians, welders, riggers and ˚tters are \nconsistently adding value to our clients™ projects.\nyongnam is an iso 9001:2008, iso 14001:2004 and oshas \n18001:2007 certi˚ed company and accredited fabricator \n\nof the highest s1 category from the singapore structural \nsteel society. our quality management system takes a \nplanned approach towards continuous improvement of \n\nour products, processes and services. yongnam has also \nachieved a bizsafe star level award.\nmoving forward, yongnam aims to be the provider of \nchoice and partner in solutions for the steel construction \nindustry.\nshaping the city skyline, adding structural and aesthetic value \nto buildings, laying solid foundations that give people the \n\ncon˚dence to build upon œ these are the ideals that yongnam has \n\nbecome synonymous with, as it grows from strength to strength, \n\nyear after year.\n'

# %%
re.search("c", "abcdef")
# Out:
# <_sre.SRE_Match object; span=(2, 3), match='c'>

# %%
page = read_pdf.getPage(1)
page_content = page.extractText()
# page_content = f_correction(page_content)
print(page_content.lower())
# Out:
# corporate pro˜le
# steel is increasingly the material of choice for the
# construction of buildings and temporary support for
# deep excavations. the advantages of using steel over
# conventional material such as concrete for building
#
# construction are numerous. the higher speed of
# construction, superior material strength to volume ratio,
# ˜exibility in design and aesthetics are just some of the
#
# bene˚ts of using steel.with 40 years of experience in steel fabrication,
# yongnam excels in adding value to steel construction.
# the group™s two production facilities in singapore and
# nusajaya, johor, malaysia have a total annual production
#
# capacity of 78,000 tonnes of steel fabrication. yongnam
# utilizes the latest fabrication technologies and design
# innovation to offer solutions to its clients on a fast-
#
# track basis. our modular strutting system continues to
# give the group a strong competitive edge in meeting
# increasingly stringent design and project requirements
#
# in infrastructure and construction projects. with a
# traceability procedure that meets the requirements of
# the singapore building and construction authority, our
# modular strutting system is the ˚rst to be certi˚ed by an
#
# independent auditor for reusability in earth retaining or
# stabilizing structures.
# yongnam™s technical and value engineering solutions for
# steel fabrication and erection have resulted in increased
# productivity, improved yield and lower costs. our in-
#
# house pool of experienced and quali˚ed engineers,
# detailers, technicians, welders, riggers and ˚tters are
# consistently adding value to our clients™ projects.
# yongnam is an iso 9001:2008, iso 14001:2004 and oshas
# 18001:2007 certi˚ed company and accredited fabricator
#
# of the highest s1 category from the singapore structural
# steel society. our quality management system takes a
# planned approach towards continuous improvement of
#
# our products, processes and services. yongnam has also
# achieved a bizsafe star level award.
# moving forward, yongnam aims to be the provider of
# choice and partner in solutions for the steel construction
# industry.
# shaping the city skyline, adding structural and aesthetic value
# to buildings, laying solid foundations that give people the
#
# con˚dence to build upon œ these are the ideals that yongnam has
#
# become synonymous with, as it grows from strength to strength,
#
# year after year.

# %%
regex = r"corporate profile"
# match = re.search(regex, page_content.lower())
match = re.search(regex, page_content.lower())
match
# Out:
# <_sre.SRE_Match object; span=(141, 158), match='corporate profile'>

# %%
page_content.lower().find('corporate profile')
# Out:
# 141

# %%
# !cd outputs
# !ls
