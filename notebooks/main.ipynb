# %%
# %pip install transformers
# %pip install PyPDF2

# %%
# %rm -rf BERT_financialReportAnalysis/

# %%
# !git clone https://github.com/francisliu2/BERT_financialReportAnalysis.git
# Out:
# Cloning into 'BERT_financialReportAnalysis'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23 (delta 9), reused 20 (delta 6), pack-reused 0
# Unpacking objects: 100% (23/23), done.

# %%
# %cd BERT_financialReportAnalysis/
# Out:
# /content/BERT_financialReportAnalysis

# %%
from companytoVector_BERT import *
from corporate_profile_extrator import *

from google.colab import files
import os
import glob

os.mkdir('outputs')

# %%
CP = glob.glob("./data/*.pdf")

# %%
model = load_model()

# %%
# %time result = company2vector(corporate_profile_1, model)
# Out:
# CPU times: user 26.9 s, sys: 620 ms, total: 27.5 s
# Wall time: 27.5 s

# %%
for i in range(len(CP)):
  name = CP[i].replace('.pdf', '') 
  name = name.replace('./data/', '')
  corporate_profile_text = get_corporate_profile(CP[i])
  result = company2vector(corporate_profile_text, model)
  np.save(name, result)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-31-576db04dd9e2> in <module>()
#       2   name = CP[i].replace('.pdf', '')
#       3   name = name.replace('./data/', '')
# ----> 4   corporate_profile_text = get_corporate_profile(CP[i])
#       5   result = company2vector(corporate_profile_text, model)
#       6   np.save(name, result)
#
# /content/BERT_financialReportAnalysis/corporate_profile_extrator.py in get_corporate_profile(file_name)
#      27
#      28             break
# ---> 29     return corporate_profile
#
# UnboundLocalError: local variable 'corporate_profile' referenced before assignment

# %%
file_name = CP[1]
pdf_file = open(file_name, 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
number_of_pages = read_pdf.getNumPages()
for p in range(number_of_pages):
    page = read_pdf.getPage(p)
    page_content = page.extractText()
    page_content = f_correction(page_content)

# %%
page = read_pdf.getPage(2)
page_content = page.extractText()
page_content = f_correction(page_content)
print(page_content)
# Out:
# Sustainability Report
#
# for the financial year ended 31 March 2018
#
# China Star Food Group Limited
#
# |
# 1
#
#
#
#
#
#
# 1.
#
# Highlights
#
# 1.1
# Corporate profile
#
# China Star Food Group Limited (
#
# ) (
#
# CSFG
#
#
# or the
#
# Company
#
# ), together with its subsidiaries (the
#
# Group
#
# ), is one
# of the leading manufacturers of healthy snack foods in the
# People
#
# s
# Republic of China (
#
# P
# RC
#
# ). The Group is engaged in the producti
# on
# and sale of sweet potato snack food products across PRC, processed
# from purple and orange
# -
# fleshed sweet potatoes.
# Currently, t
# he annual
# total production capacity
# of the Group is
# app
# roximately
# 30,000
#
# tonnes.
#
# Based in Liancheng county of Fujian Province, the Group sells its wide
# range of sweet potato snack food products to more than 300
# distributors and wholesalers, who in turn distribute the sweet potato
# snack food products, through e
# -
# commerce portals and to
# ...

# %%
regex = r"corporate[\s{,3} \n]proflle"
# match = re.search(regex, page_content.lower())
match = re.search(regex, 'corporate proflle')
match
# Out:
# <_sre.SRE_Match object; span=(0, 17), match='corporate proflle'>

# %%
page_content.lower().find('corporate profile')
# Out:
# -1

# %%
# !cd outputs
# !ls
